# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
from sklearn import datasets

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.0

# %%
import pandas as pd

# Especifica la codificación del archivo
df = pd.read_csv('anexo01.csv', encoding='ISO-8859-1')

# Mostrar los primeros registros
print(df.head())
# Out:
#        Lugar   Especie  Tamaño  Peso  VidaPromedio  Camada  CicloRepr
# 0    Canarias  Gallina     0.3  2.10             7     5.0       20.0
# 1    Cataluña  Gallina     0.6  2.40             8     6.0       20.0
# 2    Palencia  Gallina     0.8  2.30            11     6.0       20.0
# 3  Pontevedra  Gallina     0.6  1.80            11     7.0       20.0
# 4      Málaga  Gallina     0.7  1.60             5     8.0       20.0

# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('anexo01.csv', encoding='ISO-8859-1')

# %%
import pandas as pd

# Especifica la codificación correcta aquí, por ejemplo, 'ISO-8859-1'
df = pd.read_csv('anexo01.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#          Lugar   Especie  Tamaño   Peso  VidaPromedio  Camada  CicloRepr
# 0      Canarias  Gallina     0.3   2.10             7     5.0       20.0
# 1      Cataluña  Gallina     0.6   2.40             8     6.0       20.0
# 2      Palencia  Gallina     0.8   2.30            11     6.0       20.0
# 3    Pontevedra  Gallina     0.6   1.80            11     7.0       20.0
# 4        Málaga  Gallina     0.7   1.60             5     8.0       20.0
# ..          ...      ...     ...    ...           ...     ...        ...
# 585      Lleida     Vaca     1.5  1,047             8     6.0        NaN
# 586    Canarias     Vaca     1.3    867             8     7.0        NaN
# 587      Aragón     Vaca     1.2  1,146            16     7.0        NaN
# 588      Girona     Vaca     1.7    506            19     7.0        NaN
# 589        Lugo     Vaca     1.5  1,156            14    15.0        NaN
#
# [590 rows x 7 columns]

# %%
# Mostrar los primeros registros
print(df.head())

print(df.columns)
# Out:
#        Lugar   Especie  Tamaño  Peso  VidaPromedio  Camada  CicloRepr
# 0    Canarias  Gallina     0.3  2.10             7     5.0       20.0
# 1    Cataluña  Gallina     0.6  2.40             8     6.0       20.0
# 2    Palencia  Gallina     0.8  2.30            11     6.0       20.0
# 3  Pontevedra  Gallina     0.6  1.80            11     7.0       20.0
# 4      Málaga  Gallina     0.7  1.60             5     8.0       20.0
# Index(['Lugar ', 'Especie', 'Tamaño', 'Peso', 'VidaPromedio', 'Camada',
#        'CicloRepr'],
#       dtype='object')

# %%
# Estadísticas descriptivas
print(df.describe())
# Out:
#            Tamaño  VidaPromedio      Camada    CicloRepr
# count  543.000000    590.000000  590.000000   534.000000
# mean     8.587017     15.803390    6.494915   105.837079
# std     27.226141      9.543324    4.676547   135.415882
# min      0.200000      4.000000    1.000000    20.000000
# 25%      0.600000     10.000000    2.000000    29.000000
# 50%      1.160000     13.000000    5.000000    48.000000
# 75%      1.850000     18.000000   10.000000   150.000000
# max    176.000000     50.000000   16.000000  1445.000000

# %%
# Información general del DataFrame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Lugar         590 non-null    object
#  1   Especie       590 non-null    object
#  2   Tamaño        543 non-null    float64
#  3   Peso          590 non-null    object
#  4   VidaPromedio  590 non-null    int64
#  5   Camada        590 non-null    float64
#  6   CicloRepr     534 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 32.4+ KB
# None

# %%
# Eliminar filas con al menos una celda vacía
df_cleaned = df.dropna()

# %%
df
# Out:
#          Lugar   Especie  Tamaño   Peso  VidaPromedio  Camada  CicloRepr
# 0      Canarias  Gallina     0.3   2.10             7     5.0       20.0
# 1      Cataluña  Gallina     0.6   2.40             8     6.0       20.0
# 2      Palencia  Gallina     0.8   2.30            11     6.0       20.0
# 3    Pontevedra  Gallina     0.6   1.80            11     7.0       20.0
# 4        Málaga  Gallina     0.7   1.60             5     8.0       20.0
# ..          ...      ...     ...    ...           ...     ...        ...
# 585      Lleida     Vaca     1.5  1,047             8     6.0        NaN
# 586    Canarias     Vaca     1.3    867             8     7.0        NaN
# 587      Aragón     Vaca     1.2  1,146            16     7.0        NaN
# 588      Girona     Vaca     1.7    506            19     7.0        NaN
# 589        Lugo     Vaca     1.5  1,156            14    15.0        NaN
#
# [590 rows x 7 columns]

# %%
# Opcionalmente, eliminar columnas que contengan al menos una celda vacía
df_cleaned_all = df.dropna(how='all')

# %%
df
# Out:
#          Lugar   Especie  Tamaño   Peso  VidaPromedio  Camada  CicloRepr
# 0      Canarias  Gallina     0.3   2.10             7     5.0       20.0
# 1      Cataluña  Gallina     0.6   2.40             8     6.0       20.0
# 2      Palencia  Gallina     0.8   2.30            11     6.0       20.0
# 3    Pontevedra  Gallina     0.6   1.80            11     7.0       20.0
# 4        Málaga  Gallina     0.7   1.60             5     8.0       20.0
# ..          ...      ...     ...    ...           ...     ...        ...
# 585      Lleida     Vaca     1.5  1,047             8     6.0        NaN
# 586    Canarias     Vaca     1.3    867             8     7.0        NaN
# 587      Aragón     Vaca     1.2  1,146            16     7.0        NaN
# 588      Girona     Vaca     1.7    506            19     7.0        NaN
# 589        Lugo     Vaca     1.5  1,156            14    15.0        NaN
#
# [590 rows x 7 columns]

# %%
# Exportar el DataFrame limpiado a un nuevo archivo CSV
df_cleaned.to_csv('anexo01_limpio.csv', index=False)

# %%
df_filled = df.fillna(0)

df_cleaned.to_csv('anexo01_llenar_celdas.csv', index=False)

# %%
import pandas as pd

# %%
df1 = pd.read_csv('anexo01.csv', encoding='ISO-8859-1')
df2 = pd.read_csv('anexo01_llenar_celdas.csv', encoding='ISO-8859-1')
df3 = pd.read_csv('anexo01_limpio.csv', encoding='ISO-8859-1')

# %%
df1
# Out:
#          Lugar   Especie  Tamaño   Peso  VidaPromedio  Camada  CicloRepr
# 0      Canarias  Gallina     0.3   2.10             7     5.0       20.0
# 1      Cataluña  Gallina     0.6   2.40             8     6.0       20.0
# 2      Palencia  Gallina     0.8   2.30            11     6.0       20.0
# 3    Pontevedra  Gallina     0.6   1.80            11     7.0       20.0
# 4        Málaga  Gallina     0.7   1.60             5     8.0       20.0
# ..          ...      ...     ...    ...           ...     ...        ...
# 585      Lleida     Vaca     1.5  1,047             8     6.0        NaN
# 586    Canarias     Vaca     1.3    867             8     7.0        NaN
# 587      Aragón     Vaca     1.2  1,146            16     7.0        NaN
# 588      Girona     Vaca     1.7    506            19     7.0        NaN
# 589        Lugo     Vaca     1.5  1,156            14    15.0        NaN
#
# [590 rows x 7 columns]

# %%
df2
# Out:
#           Lugar   Especie  TamaÃ±o   Peso  VidaPromedio  Camada  CicloRepr
# 0       Canarias  Gallina      0.3   2.10             7     5.0       20.0
# 1      CataluÃ±a  Gallina      0.6   2.40             8     6.0       20.0
# 2       Palencia  Gallina      0.8   2.30            11     6.0       20.0
# 3     Pontevedra  Gallina      0.6   1.80            11     7.0       20.0
# 4        MÃ¡laga  Gallina      0.7   1.60             5     8.0       20.0
# ..           ...      ...      ...    ...           ...     ...        ...
# 482  Extremadura   Bufalo      2.4    885            21     1.0      332.0
# 483    Cantabria   Bufalo      2.4    956            19     1.0      334.0
# 484        JaÃ©n     Vaca      1.7    690            11     7.0     1445.0
# 485      Ourense     Vaca      1.9  1,037            11     8.0     1445.0
# 486   Santa Cruz     Vaca      1.4    903            16     8.0     1445.0
#
# [487 rows x 7 columns]

# %%
df3
# Out:
#           Lugar   Especie  TamaÃ±o   Peso  VidaPromedio  Camada  CicloRepr
# 0       Canarias  Gallina      0.3   2.10             7     5.0       20.0
# 1      CataluÃ±a  Gallina      0.6   2.40             8     6.0       20.0
# 2       Palencia  Gallina      0.8   2.30            11     6.0       20.0
# 3     Pontevedra  Gallina      0.6   1.80            11     7.0       20.0
# 4        MÃ¡laga  Gallina      0.7   1.60             5     8.0       20.0
# ..           ...      ...      ...    ...           ...     ...        ...
# 482  Extremadura   Bufalo      2.4    885            21     1.0      332.0
# 483    Cantabria   Bufalo      2.4    956            19     1.0      334.0
# 484        JaÃ©n     Vaca      1.7    690            11     7.0     1445.0
# 485      Ourense     Vaca      1.9  1,037            11     8.0     1445.0
# 486   Santa Cruz     Vaca      1.4    903            16     8.0     1445.0
#
# [487 rows x 7 columns]

# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df3 = pd.read_csv('anexo01_limpio.csv')

# %%
print(df3.describe())
# Out:
#            Tamaño  VidaPromedio      Camada    CicloRepr
# count  487.000000    487.000000  487.000000   487.000000
# mean     9.394148     14.774127    6.470226    98.466119
# std     28.641572      8.592890    4.601243   133.383457
# min      0.200000      4.000000    1.000000    20.000000
# 25%      0.590000     10.000000    2.000000    28.000000
# 50%      1.000000     12.000000    5.000000    46.000000
# 75%      1.900000     17.000000   10.000000   149.500000
# max    176.000000     50.000000   16.000000  1445.000000

# %%
df3.columns
# Out:
# Index(['Lugar ', 'Especie', 'Tamaño', 'Peso', 'VidaPromedio', 'Camada',
#        'CicloRepr'],
#       dtype='object')

# %%
df3.value_counts
# Out:
# <bound method DataFrame.value_counts of           Lugar   Especie  Tamaño   Peso  VidaPromedio  Camada  CicloRepr
# 0       Canarias  Gallina     0.3   2.10             7     5.0       20.0
# 1       Cataluña  Gallina     0.6   2.40             8     6.0       20.0
# 2       Palencia  Gallina     0.8   2.30            11     6.0       20.0
# 3     Pontevedra  Gallina     0.6   1.80            11     7.0       20.0
# 4         Málaga  Gallina     0.7   1.60             5     8.0       20.0
# ..           ...      ...     ...    ...           ...     ...        ...
# 482  Extremadura   Bufalo     2.4    885            21     1.0      332.0
# 483    Cantabria   Bufalo     2.4    956            19     1.0      334.0
# 484         Jaén     Vaca     1.7    690            11     7.0     1445.0
# 485      Ourense     Vaca     1.9  1,037            11     8.0     1445.0
# 486   Santa Cruz     Vaca     1.4    903            16     8.0     1445.0
#
# [487 rows x 7 columns]>

# %%
pip install matplotlib pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt


plt.hist(df3)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df3 = pd.read_csv('anexo01_limpio.csv')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de muestra
data = {
    'Columna1': [1, 2, 3, 4, 5],
    'Columna2': [5, 4, 3, 2, 1],
    'Columna3': [2, 3, 4, 5, 6]
}
df3 = pd.DataFrame(data)

# Calcular la matriz de correlación
correlation_matrix = df3.corr()

# Crear la gráfica de correlación usando seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

plt.show()

# %%
print(df3.columns)
# Out:
# Index(['Columna1', 'Columna2', 'Columna3'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Lugar         590 non-null    object
#  1   Especie       590 non-null    object
#  2   Tamaño        543 non-null    float64
#  3   Peso          590 non-null    object
#  4   VidaPromedio  590 non-null    int64
#  5   Camada        590 non-null    float64
#  6   CicloRepr     534 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 32.4+ KB
